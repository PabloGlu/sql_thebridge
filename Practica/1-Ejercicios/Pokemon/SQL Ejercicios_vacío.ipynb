# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicio SQL
# Para este ejercicio usaremos una base de datos de Pokemon. **Asegúrante que tienes el CSV "pokemon.csv" en la misma carpeta donde está este Notebook**. Realiza los siguientes apartados:
#
# 1. Obten una tabla con todos los campos
# 2. Obten una tabla con los campos "Name", "Type 1", "Type 2"
# 3. Obten la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
# 4. ¿Cuales son todos los "Type 1" diferentes?
# 5. ¿Cuales son todos los "Type 1" y "Type 2" diferentes?
# 6. ¿Cuáles son los pokemon de agua? "Type 1" = "Water"
# 7. Obtén una tabla con los pokemon legendarios
# 8. Obtén una tabla con los pokemon legendarios de fuego ("Type 1" = "Fire")
# 9. Obtén una tabla con los pokemon cuyo nombre empieze por "W" y tenga una defensa mayor de 100 puntos
# 10. Saca una tabla con los pokemon de la primera generación, que NO sean "Type 1" = "Psychic" y tengan una velocidad superior a 130
# 11. ¿Cuál es el pokemon con el ataque más alto?
# 12. ¿Cuál es la media de la defensa de todos los pokemon?
# 13. ¿Cuál es la media de la defensa por generación?
# 14. Calcula el máximo HP por "Type 1"
#
# **NOTA**: se recomienda añadir un `LIMIT 5` en la mayoría de apartados para evitar grandes outputs de las queries.

# %%
# Importamos paquetes
import pandas as pd
import sqlite3
cnx = sqlite3.connect(':memory:')

# Importamos datos de un CSV
df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Pasamos el DataFrame de Pandas a SQL
df.to_sql('pokemon', con=cnx, if_exists='append', index=False)

# Definimos la función para hacer queries.
def sql_query(query):
    return pd.read_sql(query, cnx)

# %%
# 1. Obten una tabla con todos los campos
query = '''
select * from pokemon
limit 5
'''

sql_query(query)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
# 2. Obten una tabla con los campos "Name", "Type 1", "Type 2"
query = '''
select Name, "Type 1", "Type 2" from pokemon
limit 5
'''

sql_query(query)
# Out:
#                     Name Type 1  Type 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN

# %%
# 3. Obten la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
query = '''
SELECT Name AS "Nombre", "Type 1" AS "Tipo 1", "Type 2" AS "Tipo 2" 
FROM pokemon
limit 5
'''

sql_query(query)
# Out:
#                   Nombre Tipo 1  Tipo 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN

# %%
# 4. ¿Cuales son todos los "Type 1" diferentes?
query = '''
SELECT distinct "Type 1" from pokemon

'''

sql_query(query)
# Out:
#       Type 1
# 0      Grass
# 1       Fire
# 2      Water
# 3        Bug
# 4     Normal
# 5     Poison
# 6   Electric
# 7     Ground
# 8      Fairy
# 9   Fighting
# 10   Psychic
# 11      Rock
# 12     Ghost
# 13       Ice
# 14    Dragon
# 15      Dark
# 16     Steel
# 17    Flying

# %%
# 5. ¿Cuales son todos los "Type 1" y "Type 2" diferentes?
query = '''
select distinct "Type 1", "Type 2" from Pokemon
'''

sql_query(query)
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1       Fire     NaN
# 2       Fire  Flying
# 3       Fire  Dragon
# 4      Water     NaN
# ..       ...     ...
# 149    Ghost   Grass
# 150   Flying  Dragon
# 151  Psychic   Ghost
# 152  Psychic    Dark
# 153     Fire   Water
#
# [154 rows x 2 columns]

# %%
# 6. ¿Cuáles son los pokemon de agua? "Type 1" = "Water"
query = '''
select "name", "Type 1" from pokemon
where "Type 1" like "Water"
'''

sql_query(query)
# Out:
#                         Name Type 1
# 0                   Squirtle  Water
# 1                  Wartortle  Water
# 2                  Blastoise  Water
# 3    BlastoiseMega Blastoise  Water
# 4                    Psyduck  Water
# ..                       ...    ...
# 107                  Froakie  Water
# 108                Frogadier  Water
# 109                 Greninja  Water
# 110                Clauncher  Water
# 111                Clawitzer  Water
#
# [112 rows x 2 columns]

# %%
# 7. Obtén una tabla con los pokemon legendarios
query = '''
select * from pokemon
where legendary like 1
'''

sql_query(query)
# Out:
#       #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying    580   90      85      100
# 1   145               Zapdos  Electric    Flying    580   90      90       85
# 2   146              Moltres      Fire    Flying    580   90     100       90
# 3   150               Mewtwo   Psychic       NaN    680  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..  ...                  ...       ...       ...    ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy    600   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 64  721            Volcanion      Fire     Water    600   80     110      120
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        95      125     85           1          1
# 1       125       90    100           1          1
# 2       125       85     90           1          1
# 3       154       90    130           1          1
# 4       154      100    130           1          1
# ..      ...      ...    ...         ...        ...
# 60      100      150     50           6          1
# 61      160      110    110           6          1
# 62      150      130     70           6          1
# 63      170      130     80           6          1
# 64      130       90     70           6          1
#
# [65 rows x 13 columns]

# %%
# 8. Obtén una tabla con los pokemon legendarios de fuego ("Type 1" = "Fire")
query = '''
select * from pokemon
where legendary like 1 and "Type 1" = "Fire"
'''
# <> 0

sql_query(query)
# Out:
#      #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0  146    Moltres   Fire  Flying    580   90     100       90      125
# 1  244      Entei   Fire     NaN    580  115     115       85       90
# 2  250      Ho-oh   Fire  Flying    680  106     130       90      110
# 3  485    Heatran   Fire   Steel    600   91      90      106      130
# 4  721  Volcanion   Fire   Water    600   80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       85     90           1          1
# 1       75    100           2          1
# 2      154     90           2          1
# 3      106     77           4          1
# 4       90     70           6          1

# %%
# 9. Obtén una tabla con los pokemon cuyo nombre empieze por "W" y tenga una defensa mayor de 100 puntos
query = '''
select * from pokemon
where name like "W%" and "Defense" > "100"
'''

sql_query(query)
# Out:
#      #                 Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  110              Weezing  Poison     NaN    490  65      90      120
# 1  413  WormadamSandy Cloak     Bug  Ground    424  60      79      105
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       85       70     60           1          0
# 1       59       85     36           4          0

# %%
# 10. Saca una tabla con los pokemon de la primera generación, que NO sean "Type 1" = "Psychic" y tengan una velocidad superior a 130
query = '''
select * from pokemon
where "Type 1" not like "Psychic" and "Speed" > 130
'''

sql_query(query)
# Out:
#      #                       Name    Type 1    Type 2  Total  HP  Attack  \
# 0   15      BeedrillMega Beedrill       Bug    Poison    495  65     150
# 1  101                  Electrode  Electric       NaN    480  60      50
# 2  142  AerodactylMega Aerodactyl      Rock    Flying    615  80     135
# 3  254      SceptileMega Sceptile     Grass    Dragon    630  70     110
# 4  291                    Ninjask       Bug    Flying    456  61      90
# 5  310    ManectricMega Manectric  Electric       NaN    575  70      75
# 6  428        LopunnyMega Lopunny    Normal  Fighting    580  65     136
# 7  617                   Accelgor       Bug       NaN    495  80      70
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       40       15       80    145           1          0
# 1       70       80       80    140           1          0
# 2       85       70       95    150           1          0
# 3       75      145       85    145           3          0
# 4       45       50       50    160           3          0
# 5       80      135       80    135           3          0
# 6       94       54       96    135           4          0
# 7       40      100       60    145           5          0

# %%
# 11. ¿Cuál es el pokemon con el ataque más alto?
query = '''
select name, attack from pokemon
order by attack DESC
limit 1
'''

sql_query(query)
# Out:
#                   Name  Attack
# 0  MewtwoMega Mewtwo X     190

# %%
# 11. ¿Cuál es el pokemon con el ataque más alto?
query = '''
select name, max(attack) from pokemon

'''

sql_query(query)
# Out:
#                   Name  max(attack)
# 0  MewtwoMega Mewtwo X          190

# %%
# 12. ¿Cuál es la media de la defensa de todos los pokemon?
query = '''
select avg(defense) from pokemon
'''
# as mean_defense
sql_query(query)
# Out:
#    avg(defense)
# 0       73.8425

# %%
# 13. ¿Cuál es la media de la defensa por generación?
query = '''
select generation, avg(defense) from pokemon
group by generation
'''

sql_query(query)
# Out:
#    Generation  avg(defense)
# 0           1     70.861446
# 1           2     73.386792
# 2           3     74.100000
# 3           4     78.132231
# 4           5     72.327273
# 5           6     76.682927

# %%
# Apartado 14. Calcula el máximo HP por "Type 1"
query = '''
select max(HP), "Type 1" from pokemon
group by "Type 1"
'''

sql_query(query)
# Out:
#     max(HP)    Type 1
# 0        86       Bug
# 1       126      Dark
# 2       125    Dragon
# 3        90  Electric
# 4       126     Fairy
# 5       144  Fighting
# 6       115      Fire
# 7        85    Flying
# 8       150     Ghost
# 9       123     Grass
# 10      115    Ground
# 11      110       Ice
# 12      255    Normal
# 13      105    Poison
# 14      190   Psychic
# 15      123      Rock
# 16      100     Steel
# 17      170     Water
